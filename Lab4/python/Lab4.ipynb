# %% [markdown]
# # Digital Signal Processing
#
# ### MsCV - ViBOT - MAIA

# %% [markdown]
# The reasons to convert signals into frequency domain is to get the idea of different frequency components it is composed of. This might help to detect the required signals and classify them, for examples, speak or speech recognition from a sound wave, noise removal from the image, or finding recurring patterns within images.

# %%
# %matplotlib inline
# %pprint off

# To make some nice plot
import matplotlib.pyplot as plt
# To play with arrays
import numpy as np
from skimage import io
from skimage import img_as_float
from matplotlib import cm
from scipy.stats import norm
from scipy import signal
# Out:
# Pretty printing has been turned OFF

# %% [markdown]
# # Discrete Fourier Transform
# The Discrete Fourier Transform (DFT) converts discrete data from a time domain into frequency domain. The DFT analyzes the finite segment in one period of an infinitely extended periodic signal, which is defined as:
# $$ X[n] = \sum^{N-1}_{k = 0} x[k] e^{-j(2\pi/N)kn}$$
#
#
# Note: The Fast Fourier Transform (FFT) is simply an algorithm to compute the DFT in a faster way!
#
# ## Exercise 1 -  ** DFT**
# **1.1** The DFT of a $5$ Hz sin wave sampled with the sampling of $f_s = 50$ Hz over 1000 (N = 1000) samples is computed as follows:

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# sin wave 
x_n = np.sin(2*np.pi*f*t) #declaring the function to compute
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('Sin wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()
# Out:
# /home/sav/Vibot/Python/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **1.2** Compute the DFT of a cosine wave, how that differs from that of a sine wave ?

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# cos wave 
x_n = np.cos(2*np.pi*f*t) #function declaration
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('Cos wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()

#The mag(F(sin))=mag(F(cos)) while real(F(sin))=-imag(F(cos)) and mag(imag(sin))=real(cos)

# %% [markdown]
# **1.3** Use square wave using the same frequncy and sampling frequency.
#
# Note use `signal.square` to create your signal.

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# square wave 
x_n= signal.square(2 * np.pi * f * t) #declaring a box to compute
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('Square wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()


#the DFT of Box function gives periodical Sinc Functions

# %% [markdown]
# **1.4** Use white Gaussian noise N = 10000.
#
# (Note use `np.random.normal` to create your noise)

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.

# gaussian white noise 
mu, sigma = 0, 1 # mean and standard deviation
x_n = np.random.normal(mu, sigma, 10000) # Declaring gaussian white noise 
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(x_n)
plt.title('White Gaussian noise')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()

# %% [markdown]
# ## Exercise 2 -  Sampling
#
# Generate and display the following signals of 1 sec duration.
# $$x[n] = 3 cos(2\pi\frac{f_{1}}{f_{s}}n) + 4 sin(2\pi\frac{f_{2}}{f_{s}}n)$$
# for $f_{1} = 5$ Hz and $f_{2} = 20$ Hz, sampled with the sampling frequencies of $f_{s} = [10, 20, 25, 40, 50, 100, 150]$

# %% [markdown]
# **2.1** Plot $x[n]$ for different sampling frequencies in time domain.

# %%
# Signal frequency and sampling frequency
f1 = 5.
f2 = 20.
fs = [10.,20.,25.,40.,50.,100.,150.,170] #170 is a buffer to plot everything

number = 10 
ranfs=7 #Length of the Fs array
i=1
n=1

 

listn=[] #create a list to backtrck everything if we have problems
x=np.zeros((ranfs,fs[ranfs])) #create a matrix to store every computation
#print x
for i in range(0,ranfs): #For each frequency , build as many points as needed corresponding to the freaquency
    u=0
    t = np.arange(0, 1., 1./fs[i]) #declaring the number of points
    for n in t:
        x[i,u]=3*np.cos(2*np.pi*f1*n)+4*np.sin(2*np.pi*f2*n) #Function
        listn.append(x) #appending to the track list
        u=u+1
        
#print listn #Test
#print len(fs) #Test


#PLOTS
for i in range(0,ranfs):
    plt.plot(x[i,:fs[i]])


for i in range(0,ranfs):
    plt.figure()
    plt.plot(x[i,:fs[i]])
    plt.title('Xn for sampling frequency of '+ str(fs[i]))
    plt.xlabel('T or N')
    plt.ylabel('Magnitude')
    plt.show()
  

    
for i in range(0,ranfs):
    plt.figure()
    plt.plot(x[i,:fs[i]])
    plt.stem(x[i,:fs[i]])
    plt.title('Xn for sampling frequency of '+ str(fs[i]) + ' and discrete signal according to N')
    plt.xlabel('T or N')
    plt.ylabel('Magnitude')
    plt.show()
  
        
        
for i in range(0,ranfs):    
    plt.figure()
    plt.stem(x[i,:fs[i]])
    
    
#So we have lot of curves, in fact almost all are bad results, only the two last ones are the only goods
#We have a sum of sin / cos, so in respect to shanon only 100 and 150 give good results and we can
#see it also on DFT, We should have 2 spikes at 5 and 20 hertz
# Out:
# /home/sav/Vibot/Python/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:30: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/sav/Vibot/Python/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:35: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/sav/Vibot/Python/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:45: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/sav/Vibot/Python/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:46: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/sav/Vibot/Python/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:56: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# **2.2.** Discuss the aliasing effects in the time domain:

# %% [markdown]
# **2.3** Compute the FFT of the above signals and display their centered frequency components.
# Discuss your observations.

# %%
for i in range (0,ranfs): #loop to do every plots and computation
# Number of samples 
    N = fs[i]
    # DFT 
    
    sig = x[i,:]
    fr=fs[i]
    # Using fftshift to have the center frequency 
    x_f = np.fft.fftshift(np.fft.fft(sig, int(N)))
    #x_f = x_f[0:N/2]

    #PLOTS
    
    plt.figure()
    plt.subplot(211)
    plt.plot(np.arange(0, 1., 1./fs[i]),x_f)
    plt.title('Sin wave Signal for fs = ' + str(fs[i]) )
    plt.xlabel('Time(sec)')
    plt.ylabel('Amplitude')
    plt.show()


    plt.subplot(313)
    plt.plot(np.abs(x_f))
    plt.title('Magnitude')
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('|X(f)|')
    plt.show()

    plt.figure
    plt.subplot(211)
    plt.plot(np.real(x_f))
    plt.title('Real')
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('Re(X(f))')
    plt.show()

    plt.subplot(212)
    plt.plot(np.imag(x_f))
    plt.title('Imaginary')
    plt.xlabel('Frequency(Hz)')
    plt.ylabel('Im(X(f))')
    plt.show()

# %% [markdown]
# ## Exercise 3 - 1D  DFT for image classification
#
# 1D DFT can be applied to analyze the frequency components along the one dimensional profile of an image. Here we want to use these information to classify the images into two different classes (**barcode** and **non-barcode** classes)
# To do so we first
# * Load the images from 1D-DFT folder
#     * **3.1** you have to normalize and resize the images to the smallest size
#     * **3.2** Take 1D profile as shown in the example and compute its DFT.
# ![](profile1.png)
#
#     * **3.3** Separate the images to two different groups of **barcode** and **non-barcode** based on their frequency spectrum of their profile
# * Some information regarding the images:
#     * There are 54 images while Images [1, 2, 6, 44:54] are barcode images and the others are similar patterns.
#
# **3.4** Discuss your results

# %%
Path = '../images/1D-DFT/'
import os, os.path
from skimage import color
from scipy import misc
from skimage import transform

import numpy as np
from scipy import ndimage

from scipy import signal
from skimage.io import imread, imshow
import matplotlib.pyplot as plt
from skimage.morphology import erosion, dilation, opening, closing, white_tophat
from skimage.morphology import black_tophat, skeletonize, convex_hull_image
from skimage.morphology import disk

import PIL
from PIL import Image


filenames = sorted([f for f in os.listdir(Path)])
rejected=0;#this variable will count the number of rejected picture

for f in filenames:
    Img = io.imread(os.path.join(Path,f),'Grey',dtype='uint8')
    
    a=Img
    Img = 255*(Img - Img.min()) / (Img.max()-Img.min()) #normalize
    height, width = Img.shape

    
    sig = Img[height/2,0:]

    


    N=width

    x_f = np.fft.fftshift(np.fft.fft(sig, int(N)*10))
    
   
        
    if (np.min(np.abs(x_f))==0)   : #Get ride of zeros values dignal
       
        rejected=rejected+1;
        continue
    
    elif (np.max(np.abs(x_f))/np.max(np.abs(x_f[0:len(x_f)/2]))>1.02): #check the variance
    
        rejected=rejected+1; 
        
        continue
    

##Print the kept picture (aka barcode)
        plt.figure()
        io.imshow(a, cmap=plt.cm.gray)
        plt.show()
        plt.figure()
        plt.plot(np.abs(x_f))
        plt.title('Magnitude')
        plt.xlabel('Frequency(Hz)')
        plt.ylabel('|X(f)|')


print (rejected)    
            
    
    ## The variability of the frequency signal is too important to extract correctly the barcodes.
    ## A step of preprocessing (before applying the FFT) could solve this issue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f674dbeb8f94> in <module>()
#      23
#      24 for f in filenames:
# ---> 25     Img = io.imread(os.path.join(Path,f),'Grey',dtype='uint8')
#      26
#      27 #plt.show()
#
# NameError: name 'io' is not defined
